# %%
"""
Bhattiprolu, S. (2021, October 13). 239 - Deep Learning training for facial emotion detection [Video]. YouTube. https://www.youtube.com/watch?v=P4OevrwTq78&t=11s

Changed 'validation' to 'test' for easy understanding
"""
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten
from tensorflow.keras.layers import Conv2D,MaxPooling2D
import os
from matplotlib import pyplot as plt
import numpy as np
import random

IMG_HEIGHT = 48
IMG_WIDTH = 48
batch_size = 32

#Project was running in wrong directory when in vscode, changed directory to the project folder
#script_dir = os.path.dirname(os.path.abspath(__file__))
#os.chdir(script_dir)

train_data_dir = 'data/train/'
test_data_dir = 'data/test/'

train_datagen = ImageDataGenerator(
                    rescale=1./255, 
                    rotation_range=30,
                    shear_range=0.3,
                    zoom_range=0.3,
                    horizontal_flip=True,
                    fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
                    train_data_dir,
                    color_mode='grayscale',
                    target_size=(IMG_HEIGHT,IMG_WIDTH),
                    batch_size=batch_size,
                    class_mode='categorical',
                    shuffle=True)

test_generator = test_datagen.flow_from_directory(
                    test_data_dir,
                    color_mode='grayscale',
                    target_size=(IMG_HEIGHT,IMG_WIDTH),
                    batch_size=batch_size,
                    class_mode='categorical',
                    shuffle=True)

#Defining labels to allow for easier console reading
class_labels=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']
img,label = train_generator.__next__()

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()
##########################################################


###########################################################
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())


train_path = "data/train/"
test_path = "data/test"

num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)


epochs=50

history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=test_generator,
                validation_steps=num_test_imgs//batch_size)

model.save('emotion_detection_model_100epochs.h5')

#plot the training and test accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Test acc')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

####################################################################
from keras.models import load_model


#Test the model
my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

#Generate a batch of images
test_img, test_lbl = test_generator.__next__()
predictions=my_model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 46, 46, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 44, 44, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 20, 20, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_17 (MaxPooling2D)      │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_22 (Dropout)                 │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_23 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,489,095 (9.50 MB)
#  Trainable params: 2,489,095 (9.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# C:\Users\viole\AppData\Roaming\Python\Python310\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 269s 298ms/step - accuracy: 0.2496 - loss: 1.8106 - val_accuracy: 0.3224 - val_loss: 1.6707
# Epoch 2/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 64us/step - accuracy: 0.2188 - loss: 1.5772 - val_accuracy: 0.3000 - val_loss: 1.6692
# Epoch 3/50
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 1:46 118ms/step - accuracy: 0.2500 - loss: 1.7334
# C:\Python310\lib\contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 95s 106ms/step - accuracy: 0.3190 - loss: 1.6910 - val_accuracy: 0.4062 - val_loss: 1.5028
# Epoch 4/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 58us/step - accuracy: 0.4375 - loss: 1.5989 - val_accuracy: 0.4000 - val_loss: 1.4409
# Epoch 5/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 87s 97ms/step - accuracy: 0.3868 - loss: 1.5621 - val_accuracy: 0.4728 - val_loss: 1.3690
# Epoch 6/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.5000 - loss: 1.6835 - val_accuracy: 0.3000 - val_loss: 1.3474
# Epoch 7/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 87s 96ms/step - accuracy: 0.4335 - loss: 1.4560 - val_accuracy: 0.5033 - val_loss: 1.2903
# Epoch 8/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 0.3750 - loss: 1.5801 - val_accuracy: 0.7000 - val_loss: 1.1115
# Epoch 9/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 90s 100ms/step - accuracy: 0.4656 - loss: 1.3935 - val_accuracy: 0.5229 - val_loss: 1.2360
# Epoch 10/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.5625 - loss: 1.3568 - val_accuracy: 0.6000 - val_loss: 1.0543
# Epoch 11/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 92s 103ms/step - accuracy: 0.4819 - loss: 1.3439 - val_accuracy: 0.5435 - val_loss: 1.2082
# Epoch 12/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.5625 - loss: 1.4186 - val_accuracy: 0.7000 - val_loss: 1.1599
# Epoch 13/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 89s 100ms/step - accuracy: 0.5000 - loss: 1.3068 - val_accuracy: 0.5354 - val_loss: 1.2009
# Epoch 14/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.4062 - loss: 1.3573 - val_accuracy: 0.6000 - val_loss: 1.1990
# Epoch 15/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 99s 110ms/step - accuracy: 0.5025 - loss: 1.2985 - val_accuracy: 0.5451 - val_loss: 1.1888
# Epoch 16/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 36us/step - accuracy: 0.3438 - loss: 1.3318 - val_accuracy: 0.8000 - val_loss: 0.6991
# Epoch 17/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 102s 114ms/step - accuracy: 0.5181 - loss: 1.2701 - val_accuracy: 0.5589 - val_loss: 1.1513
# Epoch 18/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 44us/step - accuracy: 0.5312 - loss: 1.2358 - val_accuracy: 0.5000 - val_loss: 1.3359
# Epoch 19/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 93s 104ms/step - accuracy: 0.5223 - loss: 1.2536 - val_accuracy: 0.5439 - val_loss: 1.1915
# Epoch 20/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 30us/step - accuracy: 0.4688 - loss: 1.3800 - val_accuracy: 0.8000 - val_loss: 0.8268
# Epoch 21/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 96s 107ms/step - accuracy: 0.5226 - loss: 1.2420 - val_accuracy: 0.5713 - val_loss: 1.1296
# Epoch 22/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.5938 - loss: 1.2801 - val_accuracy: 0.7000 - val_loss: 1.1651
# Epoch 23/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 95s 106ms/step - accuracy: 0.5406 - loss: 1.2238 - val_accuracy: 0.5640 - val_loss: 1.1398
# Epoch 24/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.5312 - loss: 1.2610 - val_accuracy: 0.7000 - val_loss: 0.9397
# Epoch 25/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5410 - loss: 1.2101 - val_accuracy: 0.5734 - val_loss: 1.1255
# Epoch 26/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 0.4688 - loss: 1.3404 - val_accuracy: 0.4000 - val_loss: 0.9355
# Epoch 27/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 104s 116ms/step - accuracy: 0.5355 - loss: 1.2082 - val_accuracy: 0.5805 - val_loss: 1.1010
# Epoch 28/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 35us/step - accuracy: 0.4062 - loss: 1.5346 - val_accuracy: 0.4000 - val_loss: 1.4259
# Epoch 29/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 108s 121ms/step - accuracy: 0.5493 - loss: 1.1830 - val_accuracy: 0.5766 - val_loss: 1.1087
# Epoch 30/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 38us/step - accuracy: 0.5625 - loss: 1.1556 - val_accuracy: 0.7000 - val_loss: 1.1637
# Epoch 31/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 119s 133ms/step - accuracy: 0.5431 - loss: 1.1961 - val_accuracy: 0.5798 - val_loss: 1.1032
# Epoch 32/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.5312 - loss: 1.1112 - val_accuracy: 0.4000 - val_loss: 1.6034
# Epoch 33/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 90s 100ms/step - accuracy: 0.5514 - loss: 1.1783 - val_accuracy: 0.5843 - val_loss: 1.0934
# Epoch 34/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 34us/step - accuracy: 0.5625 - loss: 1.0787 - val_accuracy: 0.4000 - val_loss: 1.2224
# Epoch 35/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5505 - loss: 1.1766 - val_accuracy: 0.5898 - val_loss: 1.0933
# Epoch 36/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 33us/step - accuracy: 0.5625 - loss: 1.1083 - val_accuracy: 0.5000 - val_loss: 1.2013
# Epoch 37/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5584 - loss: 1.1633 - val_accuracy: 0.5843 - val_loss: 1.1005
# Epoch 38/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.6875 - loss: 0.8790 - val_accuracy: 0.6000 - val_loss: 1.2311
# Epoch 39/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 87s 97ms/step - accuracy: 0.5560 - loss: 1.1656 - val_accuracy: 0.5702 - val_loss: 1.1168
# Epoch 40/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 32us/step - accuracy: 0.6250 - loss: 1.0044 - val_accuracy: 0.8000 - val_loss: 0.6118
# Epoch 41/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5665 - loss: 1.1513 - val_accuracy: 0.5873 - val_loss: 1.0825
# Epoch 42/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.5625 - loss: 1.1083 - val_accuracy: 0.5000 - val_loss: 1.0867
# Epoch 43/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5584 - loss: 1.1546 - val_accuracy: 0.5857 - val_loss: 1.0857
# Epoch 44/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.6250 - loss: 1.1634 - val_accuracy: 0.4000 - val_loss: 1.2584
# Epoch 45/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5651 - loss: 1.1416 - val_accuracy: 0.5844 - val_loss: 1.1000
# Epoch 46/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.5938 - loss: 1.2057 - val_accuracy: 0.7000 - val_loss: 0.7776
# Epoch 47/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 88s 98ms/step - accuracy: 0.5678 - loss: 1.1414 - val_accuracy: 0.5991 - val_loss: 1.0566
# Epoch 48/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.5000 - loss: 1.0686 - val_accuracy: 0.4000 - val_loss: 1.3429
# Epoch 49/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 89s 99ms/step - accuracy: 0.5707 - loss: 1.1402 - val_accuracy: 0.5880 - val_loss: 1.0828
# Epoch 50/50
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 31us/step - accuracy: 0.6250 - loss: 0.9555 - val_accuracy: 0.7000 - val_loss: 0.8489
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Accuracy =  0.46875
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 162
#     160 cm = confusion_matrix(test_labels, predictions)
#     161 #print(cm)
# --> 162 import seaborn as sns
#     163 sns.heatmap(cm, annot=True)
#     165 class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
sns.heatmap(cm, annot=True)

class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
